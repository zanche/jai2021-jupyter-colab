# %% [markdown]
# # Estudo de Caso - Spotify 2020
#
# Para apresentar ciência de dados no Jupyter, usaremosdados obtidos a partir das paradas semanais de sucesso do Spotify durante 2020.
#
# A figura a seguir apresenta o esquema do conjunto de dados, que está no diretório `../dataset`
#
# ![image.png](https://drive.google.com/uc?export=view&id=1VN2mPgRQbgdiHNK8lcHx_UuRJRGvUNt9)
#
# O próximo notebook ([2.3.Introducao.Pandas.ipynb](https://drive.google.com/file/d/1OTmqomFWXCH-3rkQPU9ujORqetuR2YfG/view?usp=sharing)) apresenta uma introdução inicial ao pandas.
