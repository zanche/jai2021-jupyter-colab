# %% [markdown]
# # Estrutura geral de um Notebook
#
# Notebooks possuem célula de Markdown, código e bruta.
#
# <style>
#     .tutorial-text {
#        color: red;
#     }
# </style>

# %% [markdown]
# ## Fibonacci

# %%
def fib(x):
    if x <= 1:
        return x
    return fib(x-1) + fib(x-2)
fib(10)
# Out:
# 55

# %% [markdown]
# Vamos **visualizar** os números

# %%
from matplotlib import pyplot
# %matplotlib inline
x = range(15)
y = [fib(n) for n in x]
pyplot.plot(x, y);

# %% [raw]
# Esta célula **não** é nem Markdown nem Código

# %% [markdown]
# ## Conclusão
#
# Este notebook apresentou brevemente os tipos de células que existem em notebooks.
#
# O próximo notebook ([2.2.Estudo.de.Caso.ipynb](https://drive.google.com/file/d/17xD_ar9tRSdJtFs4zSIXlE5MccpZUKfO/view?usp=sharing)) apresenta o estudo de caso que usaremmos neste tutorial.
